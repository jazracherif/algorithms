# %% [markdown]
# #### Given an array of integers, return indices of the two numbers such that they add up to a specific target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# Example:
# ```
# Given nums = [2, 7, 11, 15], target = 9,
#
# Because nums[0] + nums[1] = 2 + 7 = 9,
# return [0, 1].
# ```

# %%
# NOT WORKING

class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        n = len(nums)
        
        nums = sorted(nums)
        
        myvalue = []
        def findTwoSum(nums, start, end, target, myvalue):
            print (nums, start, end, target)
            
            if nums[end] + nums[start] == target:
                myvalue.append([start,end])  
            elif nums[end] > target and nums[start] > target:
                return    
            else:
                middle = int((end-start)/2)
                if nums[middle] < target:                
                    findTwoSum(nums, start, middle, target,myvalue)
                else:
                    findTwoSum(nums,  middle, end, target,myvalue)
                
        findTwoSum(nums, 0, n-1, target, myvalue)        
        return myvalue 
    

mysol = Solution()

print ("solution", mysol.twoSum([2, 7, 11, 15], 18))
# Out:
# [2, 7, 11, 15] 0 3 18
# [2, 7, 11, 15] 0 1 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# [2, 7, 11, 15] 0 0 18
# ...
